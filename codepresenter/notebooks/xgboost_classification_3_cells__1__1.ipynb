# %%
import pandas as pdfrom sklearn.datasets import make_classificationfrom sklearn.model_selection import train_test_split# Create a small synthetic classification datasetX, y = make_classification(    n_samples=200,    n_features=6,    n_informative=4,    n_redundant=1,    n_classes=2,    random_state=42)feature_names = [f"feature_{i}" for i in range(1, 7)]df = pd.DataFrame(X, columns=feature_names)df["target"] = yprint(df.head())X_train, X_test, y_train, y_test = train_test_split(    df[feature_names],    df["target"],    test_size=0.2,    random_state=42,    stratify=df["target"])print("\nTrain shape:", X_train.shape)print("Test shape:", X_test.shape)
